# %%
import json
import urllib.request

# %%
url = (
    'https://github.com/galaxyproject/galaxy_codex/raw/8d7691124fb2f69fb3ffed1fa1190319fd707a90'
    '/communities/imaging/resources/tools_filtered_by_ts_categories.json'
)
filename = 'tools.json'
urllib.request.urlretrieve(url, filename)
# Out:
# ('tools.json', <http.client.HTTPMessage at 0x1084b0310>)

# %%
with open(filename) as fin:
    tools = json.load(fin)

# %%
def sum_runs_on_main_servers(tool):
    s = 0
    for key, value in tool.items():
        if key.startswith('Suite runs (usegalaxy.'):
            s += value
    return s

# %%
counters = dict()
min_unique_users_eu = 0
min_unique_users_main = 0

for tool in tools:
    if any(
        [
            'bmcv' in (tool[key].lower() if tool[key] else '')
            for key in ['Homepage', 'Suite source', 'Suite parsed folder']
        ]
    ):
        print(tool['Suite ID'])
        for key in ['Suite runs (usegalaxy.eu)', 'Suite runs on main servers']:
            counters.setdefault(key, 0)
            counters[key] += tool[key]
        counters.setdefault('Suite runs on main servers*', 0)
        counters['Suite runs on main servers*'] += sum_runs_on_main_servers(tool)
        min_unique_users_eu = max((min_unique_users_eu, tool['Suite users (usegalaxy.eu)']))
        min_unique_users_main = max((min_unique_users_main, tool['Suite users on main servers']))

print()
for key, value in counters.items():
    print(f'{key}: {value}')
    
print()
print(f'Unique users on EU: ≥{min_unique_users_eu}')
print(f'Unique users on main: ≥{min_unique_users_main}')
# Out:
# 2d_auto_threshold
# 2d_feature_extraction
# 2d_filter_segmentation_by_features
# 2d_histogram_equalization
# 2d_simple_filter
# anisotropic_diffusion
# background_removal
# bfconvert
# binary2labelimage
# binaryimage2points
# bioformats2raw
# color_deconvolution
# colorize_labels
# concat_channels
# coordinates_of_roi
# count_objects
# curve_fitting
# detection_viz
# image_info
# image_math
# image_registration_affine
# imagecoordinates_flipaxis
# label_to_binary
# labelimage2points
# landmark_registration
# mahotas_features
# mergeneighboursinlabelimage
# morphological_operations
# orientationpy
# overlay_images
# permutate_axis
# plantseg
# points2labelimage
# points_association_nn
# projective_transformation
# projective_transformation_points
# repeat_channels
# rfove
# scale_image
# segmetrics
# slice_image
# split_labelmap
# spot_detection_2d
# superdsm
# visceral_evaluatesegmentation
# voronoi_tesselation
# wsi_extract_top_view
#
# Suite runs (usegalaxy.eu): 101005
# Suite runs on main servers: 242859
# Suite runs on main servers*: 102763
#
# Unique users on EU: ≥124
# Unique users on main: ≥433

# %% [markdown]
# @paulzierep on the discrepancy between `Suite runs on main servers` and `Suite runs on main servers*`:
# > [Hier](https://github.com/galaxyproject/galaxy_codex/blob/8d7691124fb2f69fb3ffed1fa1190319fd707a90/communities/imaging/resources/tools_filtered_by_ts_categories.json#L95C10-L95C36) scheint die summe falsch zu sein, warum ? weiß ich leider auch gerade nicht, evt. ein bug den wir seit demg gefixed haben
